# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.animation import FuncAnimation

# %%
#function to plot individual movement of fly
def ploting(fly1):
    x = fly1[['x']]
    y = fly1[['y']]
    t = fly1['seconds']
    plt.figure(figsize=(12,10))
    plt.scatter(x, y, c=t, s=10, cmap='BuPu')
    plt.colorbar()

# %%
#plotting individual movement of fly-16figures
nums = range(1,10)
for num in nums:
    path = '.\\distances\\fly-0%d.csv' %num
    data = pd.read_csv(path)
    ploting(data)
nums = range(10,17)
for num in nums:
    path = '.\\distances\\fly-%d.csv' %num
    data = pd.read_csv(path)
    ploting(data)

plt.show;

# %%
#plotting individual movement of fly using subplot
def ploting(dir, i, name, arena):
    nums1 = range(1,10)
    for num in nums1:
        path = dir+'\\distances\\fly-0%d.csv' %num
        globals()['fly{}'.format(num)] = pd.read_csv(path)

    nums2 = range(10,i+1)
    for num in nums2:
        path = dir+'\\distances\\fly-%d.csv' %num
        globals()['fly{}'.format(num)] = pd.read_csv(path)
    nums = range(1, i+1) 
    for num in nums:
        globals()['x_{}'.format(num)] = globals()['fly{}'.format(num)][['x']]
        globals()['y_{}'.format(num)] = globals()['fly{}'.format(num)][['y']]
        globals()['t_{}'.format(num)] = globals()['fly{}'.format(num)]['seconds']




    fig, axes = plt.subplots(4,4)
    fig.set_size_inches((20,20))
    plt.subplots_adjust(wspace=0.3, hspace=0.3)

    #전체 제목 설정
    fig.suptitle('DGRP {} ({})'.format(name, arena), fontsize= 30)


    var = 1
    for row in range(4):
        for col in range(4):
            axes[row,col].scatter(globals()['x_{}'.format(var)], globals()['y_{}'.format(var)], c=globals()['t_{}'.format(var)], s=5,cmap='BuPu')
            axes[row,col].set_xlim(0,800) # set the size of the x axis
            axes[row,col].set_ylim(0,800) # set the size of the y axis
            var += 1
    
    plt.savefig('.\\DGRP%d-%d.png' %(name, arena)) #save the figure in current directory
    plt.show;
dir = '.'
ploting(dir,16,100, 1)

# %%
#plot one fly to check

plt.figure(figsize=(12,10))
plt.scatter(x_8, y_8, c=t_8, s=1, cmap='BuPu') #set the fly number 
plt.xlim(0,800)
plt.ylim(0,800)
plt.colorbar()
plt.show()

# %%
#plotting the arena
def ploting2(dir, i, name, arena):
    # read csv file and set the name
    nums1 = range(1,10)
    for num in nums1:
        path = dir+'\\distances\\fly-0%d.csv' %num
        globals()['fly{}'.format(num)] = pd.read_csv(path)

    nums2 = range(10,i+1)
    for num in nums2:
        path = dir+'\\distances\\fly-%d.csv' %num
        globals()['fly{}'.format(num)] = pd.read_csv(path)
    nums = range(1, i+1) 
    for num in nums:
        globals()['x_{}'.format(num)] = globals()['fly{}'.format(num)][['x']]
        globals()['y_{}'.format(num)] = globals()['fly{}'.format(num)][['y']]
        globals()['t_{}'.format(num)] = globals()['fly{}'.format(num)]['seconds']


    #전체 제목 설정
    plt.figure(figsize=(20,20))
    cmaplist = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu', 'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
    for var in range(1,i):
        plt.scatter(globals()['x_{}'.format(var)], globals()['y_{}'.format(var)], c=globals()['t_{}'.format(var)], s=5,cmap=cmaplist[var]) 

   
    plt.title('Total Roadmap of DGRP {} ({})'.format(name, arena), fontsize= 30)
    plt.savefig('.\\DGRP%d-%d_total.png' %(name, arena)) #save the figure in current directory
    plt.show;
dir = '.'
ploting2(dir,16,100, 1)

# %%
#testing with fly1 in DGRP100 arena 1
fly1 = pd.read_csv('fly-01.csv')

min =len(fly1)
fly1 = fly1.iloc[min-225:,1:]
#filter = np.where(time<=120)

#min =len(filter[0])
#arr2 = time[filter]
#min = len(arr2)
print(fly1)
# Out:
#         frame     seconds           x           y  fly-01      fly-02  \
# 1800  16197.0  541.010151  313.066513  609.214783     0.0  377.097931
# 1801  16205.0  541.277366  317.055496  604.407410     0.0  370.184758
# 1802  16213.0  541.544581  334.802994  594.050659     0.0  349.587049
# 1803  16221.0  541.811796  355.071945  569.476807     0.0  319.701057
# 1804  16229.0  542.079011  357.916519  553.628540     0.0  307.944264
# ...       ...         ...         ...         ...     ...         ...
# 2020  17957.0  599.797449  238.560547  111.753071     0.0  465.273982
# 2021  17965.0  600.064664  229.158310  122.629513     0.0  466.898770
# 2022  17973.0  600.331879  207.912666  133.487869     0.0  476.664978
# 2023  17981.0  600.599094  218.333488  137.088974     0.0  468.088507
# 2024  17989.0  600.866309  198.299690  154.320610     0.0  477.929353
#
#           fly-03      fly-04      fly-05      fly-06  ...      fly-15  \
# 1800  540.764043  339.686984  521.170990  443.898423  ...  518.850078
# 1801  535.836829  330.286984  510.170154  440.552416  ...  514.272726
# 1802  523.332586  328.927401  478.864682  433.719469  ...  502.966189
# 1803  496.984675  317.270259  426.831715  412.173898  ...  478.348201
# 1804  479.694100  290.101523  404.531248  400.727556  ...  463.653275
# ...          ...         ...         ...         ...  ...         ...
# 2020  450.971537  147.368507  307.584549  549.008744  ...  111.651589
# 2021  453.749597  149.011939  311.729723  538.391943  ...   97.814191
# 2022  467.448125  166.879976  326.243450  517.776419  ...   78.985649
# 2023  456.476406  156.132147  315.228532  501.619405  ...   79.895552
# 2024  467.790118  173.045891  327.388239  474.118914  ...   56.973995
#
#           fly-16        mean         std  top-01  top-02  top-03    top-mean  \
# 1800  491.378239  381.636265  142.110690   fly-3   fly-5  fly-15  216.502261
# 1801  485.511879  379.229238  141.599328   fly-3  fly-15   fly-5  216.502261
# 1802  476.147181  374.027159  136.862137   fly-3   fly-9  fly-15  284.332937
# 1803  452.401015  356.524064  126.318964   fly-3   fly-9  fly-15  284.332937
# 1804  438.024589  344.883664  119.944782   fly-3   fly-9  fly-15  284.332937
# ...          ...         ...         ...     ...     ...     ...         ...
# 2020  251.834485  267.552391  161.601350   fly-6   fly-2   fly-9  319.357159
# 2021  237.954388  264.133194  160.979374   fly-6   fly-2   fly-3  186.224555
# 2022  215.991873  262.095219  160.223773   fly-6   fly-2   fly-3  186.224555
# 2023  218.149055  255.886253  156.129647   fly-6   fly-2   fly-3  186.224555
# 2024  193.014129  251.599439  154.930903   fly-2   fly-6   fly-3  186.224555
#
#          top-std  interaction
# 1800   91.924635          0.0
# 1801   91.924635          0.0
# 1802  187.850162          0.0
# 1803  187.850162          0.0
# 1804  187.850162          0.0
# ...          ...          ...
# 2020  213.987349          1.0
# 2021  140.816799          2.0
# 2022  140.816799          2.0
# 2023  140.816799          2.0
# 2024  140.816799          3.0
#
# [225 rows x 28 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import numpy as np
from matplotlib.animation import FuncAnimation
# %matplotlib notebook

# %%
def animate(i):
    data = pd.read_csv(r'fly-01.csv', skiprows=1)
    x = fly1['x'] # assigning 'Time' column to x variable
    y = fly1['x'] # assigning 'HRR' column to y variable
    
    plt.cla() # clear axis after plotting individual lines
    plt.plot(x, y, label = 'HRR') # selecting the x and y variables to plot
    plt.title('Dgrp100 arena1')


ani = FuncAnimation(plt.gcf(), animate, frames=2000, repeat = False)
ani.save('DGRP100_arane1_fly1.gif', writer='imagemagick')
# Out:
# <div id='4aca54ae-5547-485c-a0fd-7c3ff1763060'></div>
# MovieWriter imagemagick unavailable; using Pillow instead.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.animation import FuncAnimation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

df = pd.read_csv("C:\\Users\\usr\\Documents\\Sublime\\return_to_windows\\Files\\cod2019.txt", sep='\t')
dg = df['Likes']

x_data = []
y_data = []

fig, ax = plt.subplots()
ax.set_xlim(0, len(dg))
ax.set_ylim(0, dg.max() * 1.04) # multiplied with 1.04 to add some gap in y-axis
line, = ax.plot(0, 0)

ax.set_xlabel('Part No')
ax.set_ylabel('Number of Likes')
ax.set_title('Likes in Call of Duty 2019')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
fig = plt.gcf()
fig.set_size_inches(12.8, 7.2)  # 720p output
x = np.array(dg.index)
y = np.array(dg)


def augment(xold, yold, numsteps):
    xnew = []
    ynew = []
    for i in range(len(xold) - 1):
        difX = xold[i + 1] - xold[i]
        stepsX = difX / numsteps
        difY = yold[i + 1] - yold[i]
        stepsY = difY / numsteps
        for s in range(numsteps):
            xnew = np.append(xnew, xold[i] + s * stepsX)
            ynew = np.append(ynew, yold[i] + s * stepsY)
    return xnew, ynew


XN, YN = augment(x, y, 3)
augmented = pd.DataFrame(YN, XN)

ylikes = augmented[0].reset_index()  # Index reset to avoid key error

def animation_frame(i):
    x_data.append(augmented.index[i])
    y_data.append(ylikes[0][i])

    line.set_xdata(x_data)
    line.set_ydata(y_data)
    return line,

    plt.cla()
    plt.tight_layout()


anima = animation.FuncAnimation(fig, func=animation_frame, frames=len(augmented), interval=80)
plt.show()

Writer = animation.writers['ffmpeg']
writer = Writer(fps=15, bitrate=1000)
anima.save('lines3.mp4', writer=writer)

# %%
fly1 = pd.read_csv('fly-01.csv')
fig = plt.figure()
ax = plt.axes(xlim=(0,800), ylim=(0,800))
line, = ax.plot([], [], lw=3)


def animate(i):
  x = fly1[['x']] 
  y = fly1[['y']] 
  line.set_data(x, y)
  return line,


# anim = FuncAnimation(fig, animate, frames=200, interval=50)
anim = FuncAnimation(fig, animate, frames=2000)
# Out:
# <div id='604bf1d5-61c8-4e01-a352-8d8d53f22720'></div>
# MovieWriter imagemagick unavailable; using Pillow instead.

# %%
# Generate data...
x = fly1[['x']]
y = fly1[['y']]
t = fly1['seconds']

plt.figure(figsize=(12,10))
plt.scatter(x, y, c=t, s=10, cmap='BuPu')
plt.colorbar()
plt.show()

# pip makeaxis 알아서 배율을 맞추주지만 시간이 오래 걸린다는 단점이 있음.
# plt.plot


#x = fly1[['x']]
#y = fly1[['y']]
#t = fly1[['seconds']]
#fig ,ax = plt.subplot(figsize= d, constrained_layout)
#plt.plot(x,y);
#plt.subplot(figsize )
#constrained_lay"""
# Out:
# "\nx = fly1[['x']]\ny = fly1[['y']]\nt = fly1[['seconds']]\nfig ,ax = plt.subplot(figsize= d, constrained_layout)\nplt.plot(x,y);\nplt.subplot(figsize )\nconstrained_lay"
